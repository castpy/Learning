# %% [markdown]
# ## Importar pandas

# %%
import pandas as pd

# %% [markdown]
# ## Ler DataFrame de arquivo CSV

# %%
data = pd.read_csv('titanic/train.csv')

# %% [markdown]
# ## Primeiras Linhas

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Últimas Linhas

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Informações do DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Resumo Estatístico de Campos Numéricos

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Resumo estatístico de campos Categóricos

# %%
data.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# ## Renomear colunas

# %%
data.rename({
    'Name' : 'Nome',
    'Sex' : 'Sexo',
    'Age' : 'Idade'
    }, axis=1, inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome    Sexo  Idade  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male   27.0      0
# 887                       Graham, Miss. Margaret Edith  female   19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male   26.0      0
# 890                                Dooley, Mr. Patrick    male   32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Ou isso pode ser feito com
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Nome', 'Sexo', 'Idade', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 'IrmaoConjuje',
       'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']

# %%
data.columns
# Out:
# Index(['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade',
#        'IrmaoConjuje', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine',
#        'Embarque'],
#       dtype='object')

# %% [markdown]
# # Selecionar Colunas Específicas

# %%
data[['Nome', 'Sexo', 'Idade', 'Sobreviveu']].head()
# Out:
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    Sobreviveu
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0

# %% [markdown]
# ## Selecionando apenas uma coluna - Data Series

# %%
data[['Nome']].head() #Mosta o data frame
#data['Nome'].head() #Mostra o datasures
# Out:
#                                                 Nome
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %% [markdown]
# ## Funções matemáticas embutidas

# %%
data['Idade'].mean()
# Out:
# 29.69911764705882

# %%
data['Idade'].sum()
# Out:
# 21205.17

# %%
data['Idade'].count()
# Out:
# 714

# %%
data['Idade'].median()
# Out:
# 28.0

# %%
data['Idade'].max()
# Out:
# 80.0

# %%
data['Idade'].min()
# Out:
# 0.42

# %%
data['Idade'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
data['Idade'].idxmax()
# Out:
# 630

# %%
data['Idade'].idxmin()
# Out:
# 803

# %% [markdown]
# ## Selecionando pelo Index - iloc

# %%
data.iloc[803]
# Out:
# IdPassageiro                                804
# Sobreviveu                                    1
# Classe                                        3
# Nome            Thomas, Master. Assad Alexander
# Sexo                                       male
# Idade                                      0.42
# IrmaoConjuje                                  0
# PaisFilhos                                    1
# Bilhete                                    2625
# Tarifa                                   8.5167
# Cabine                                      NaN
# Embarque                                      C
# Name: 803, dtype: object

# %%
data.iloc[[803]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                             Nome  Sexo  \
# 803           804           1       3  Thomas, Master. Assad Alexander  male
#
#      Idade  IrmaoConjuje  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 803   0.42             0           1    2625  8.5167    NaN        C

# %%
data.iloc[[630]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Sexo  Idade  IrmaoConjuje  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 630  male   80.0             0           0   27042    30.0    A23        S

# %%
data.iloc[[803, 630]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 803           804           1       3       Thomas, Master. Assad Alexander
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Sexo  Idade  IrmaoConjuje  PaisFilhos Bilhete   Tarifa Cabine Embarque
# 803  male   0.42             0           1    2625   8.5167    NaN        C
# 630  male  80.00             0           0   27042  30.0000    A23        S

# %%
data['Nome'].iloc[2]
# Out:
# 'Heikkinen, Miss. Laina'

# %% [markdown]
# ## Operador de seleção "loc"

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe']].loc[data['Sexo']=='male'].head()
# Out:
#    Idade  Sexo   Tarifa  Classe
# 0   22.0  male   7.2500       3
# 4   35.0  male   8.0500       3
# 5    NaN  male   8.4583       3
# 6   54.0  male  51.8625       1
# 7    2.0  male  21.0750       3

# %% [markdown]
# ## Selecionando com múltiplas condições

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade'] >=3) & (data['Idade'] <= 10) & (data['Sobreviveu']) & (data['Sexo'] == 'male')]
# Out:
#      Idade  Sexo   Tarifa  Classe  Sobreviveu
# 165    9.0  male  20.5250       3           1
# 193    3.0  male  26.0000       2           1
# 261    3.0  male  31.3875       3           1
# 348    3.0  male  15.9000       3           1
# 407    3.0  male  18.7500       2           1
# 445    4.0  male  81.8583       1           1
# 489    9.0  male  15.9000       3           1
# 549    8.0  male  36.7500       2           1
# 751    6.0  male  12.4750       3           1
# 869    4.0  male  11.1333       3           1

# %%
data[['Nome', 'Idade', 'Sexo', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade'] <= 14) & (data['Classe'] == 3) & ~ (data['Sobreviveu'])]
# Out:
#                                         Nome  Idade    Sexo  Classe  \
# 7             Palsson, Master. Gosta Leonard    2.0    male       3
# 14      Vestrom, Miss. Hulda Amanda Adolfina   14.0  female       3
# 16                      Rice, Master. Eugene    2.0    male       3
# 24             Palsson, Miss. Torborg Danira    8.0  female       3
# 50                Panula, Master. Juha Niilo    7.0    male       3
# 59        Goodwin, Master. William Frederick   11.0    male       3
# 63                     Skoog, Master. Harald    4.0    male       3
# 119        Andersson, Miss. Ellis Anna Maria    2.0  female       3
# 147         Ford, Miss. Robina Maggie "Ruby"    9.0  female       3
# 164             Panula, Master. Eino Viljami    1.0    male       3
# 171                     Rice, Master. Arthur    4.0    male       3
# 182    Asplund, Master. Clarence Gustaf Hugo    9.0    male       3
# 205               Strom, Miss. Telma Matilda    2.0  female       3
# 278                       Rice, Master. Eric    7.0    male       3
# 374               Palsson, Miss. Stina Viola    3.0  female       3
# 386          Goodwin, Master. Sidney Leonard    1.0    male       3
# 419                Van Impe, Miss. Catharina   10.0  female       3
# 480           Goodwin, Master. Harold Victor    9.0    male       3
# 541     Andersson, Miss. Ingeborg Constanzia    9.0  female       3
# 542        Andersson, Miss. Sigrid Elisabeth   11.0  female       3
# 634                       Skoog, Miss. Mabel    9.0  female       3
# 642            Skoog, Miss. Margit Elizabeth    2.0  female       3
# 683              Goodwin, Mr. Charles Edward   14.0    male       3
# 686                 Panula, Mr. Jaako Arnold   14.0    male       3
# 731                 Hassan, Mr. Houssein G N   11.0    male       3
# 787                Rice, Master. George Hugh    8.0    male       3
# 813       Andersson, Miss. Ebba Iris Alfrida    6.0  female       3
# 819             Skoog, Master. Karl Thorsten   10.0    male       3
# 824             Panula, Master. Urho Abraham    2.0    male       3
# 850  Andersson, Master. Sigvard Harald Elias    4.0    male       3
# 852                  Boulos, Miss. Nourelain    9.0  female       3
#
#      Sobreviveu
# 7             0
# 14            0
# 16            0
# 24            0
# 50            0
# 59            0
# 63            0
# 119           0
# 147           0
# 164           0
# 171           0
# 182           0
# 205           0
# 278           0
# 374           0
# 386           0
# 419           0
# 480           0
# 541           0
# 542           0
# 634           0
# 642           0
# 683           0
# 686           0
# 731           0
# 787           0
# 813           0
# 819           0
# 824           0
# 850           0
# 852           0

# %% [markdown]
# ## map e replace

# %%
data['Sexo'].map({'male': 'Homem', 'famale':'Mulher'})
# Out:
# 0      Homem
# 1        NaN
# 2        NaN
# 3        NaN
# 4      Homem
#        ...
# 886    Homem
# 887      NaN
# 888      NaN
# 889    Homem
# 890    Homem
# Name: Sexo, Length: 891, dtype: object

# %%
data['Sexo'].replace(['male', 'famale'],['Homem', 'Mulher'], inplace=True)
data['Sexo']
# Out:
# 0       Homem
# 1      female
# 2      female
# 3      female
# 4       Homem
#         ...
# 886     Homem
# 887    female
# 888    female
# 889     Homem
# 890     Homem
# Name: Sexo, Length: 891, dtype: object

# %% [markdown]
# ## Groupby - Agrupar por

# %%
data.groupby('Sexo').count()
# Out:
#         IdPassageiro  Sobreviveu  Classe  Nome  Idade  IrmaoConjuje  \
# Sexo
# Homem            577         577     577   577    453           577
# female           314         314     314   314    261           314
#
#         PaisFilhos  Bilhete  Tarifa  Cabine  Embarque
# Sexo
# Homem          577      577     577     107       577
# female         314      314     314      97       312

# %%
data.groupby('Classe').mean()
# Out:
#         IdPassageiro  Sobreviveu      Idade  IrmaoConjuje  PaisFilhos  \
# Classe
# 1         461.597222    0.629630  38.233441      0.416667    0.356481
# 2         445.956522    0.472826  29.877630      0.402174    0.380435
# 3         439.154786    0.242363  25.140620      0.615071    0.393075
#
#            Tarifa
# Classe
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
data.groupby('Tarifa').mean()
# Out:
#           IdPassageiro  Sobreviveu    Classe      Idade  IrmaoConjuje  \
# Tarifa
# 0.0000          516.40    0.066667  1.933333  35.142857          0.00
# 4.0125          379.00    0.000000  3.000000  20.000000          0.00
# 5.0000          873.00    0.000000  1.000000  33.000000          0.00
# 6.2375          327.00    0.000000  3.000000  61.000000          0.00
# 6.4375          844.00    0.000000  3.000000  34.500000          0.00
# ...                ...         ...       ...        ...           ...
# 227.5250        589.25    0.750000  1.000000  32.666667          0.25
# 247.5208        209.50    0.500000  1.000000  37.000000          0.00
# 262.3750        527.50    1.000000  1.000000  19.500000          2.00
# 263.0000        224.50    0.500000  1.000000  32.500000          2.50
# 512.3292        559.00    1.000000  1.000000  35.333333          0.00
#
#           PaisFilhos
# Tarifa
# 0.0000      0.000000
# 4.0125      0.000000
# 5.0000      0.000000
# 6.2375      0.000000
# 6.4375      0.000000
# ...              ...
# 227.5250    0.000000
# 247.5208    1.000000
# 262.3750    2.000000
# 263.0000    2.500000
# 512.3292    0.333333
#
# [248 rows x 6 columns]

# %%
data.groupby(['Sexo', 'Classe']).mean()
# Out:
#                IdPassageiro  Sobreviveu      Idade  IrmaoConjuje  PaisFilhos  \
# Sexo   Classe
# Homem  1         455.729508    0.368852  41.281386      0.311475    0.278689
#        2         447.962963    0.157407  30.740707      0.342593    0.222222
#        3         455.515850    0.135447  26.507589      0.498559    0.224784
# female 1         469.212766    0.968085  34.611765      0.553191    0.457447
#        2         443.105263    0.921053  28.722973      0.486842    0.605263
#        3         399.729167    0.500000  21.750000      0.895833    0.798611
#
#                    Tarifa
# Sexo   Classe
# Homem  1        67.226127
#        2        19.741782
#        3        12.661633
# female 1       106.125798
#        2        21.970121
#        3        16.118810

# %% [markdown]
# ## Crosstab

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], margins=True)
# Out:
# Classe        1    2    3  All
# Sobreviveu
# 0            80   97  372  549
# 1           136   87  119  342
# All         216  184  491  891

# %%
pd.crosstab(data['Sobreviveu'], data['Sexo'], margins=True)
# Out:
# Sexo        Homem  female  All
# Sobreviveu
# 0             468      81  549
# 1             109     233  342
# All           577     314  891

# %% [markdown]
# ## Ordenando Dados

# %% [markdown]
# ## Lidando com dados faltando $\rightarrow$ NaN - Not a Number

# %% [markdown]
# ## Deletando Coluna ou Linha

# %% [markdown]
# ## Apply e Lambda

# %% [markdown]
# ## Variáveis Dummy | HotEncoder

# %% [markdown]
# ## Concatenando DataFrames

# %% [markdown]
# # Expressões Regulares
#
# .  - qualquer caracter
# <br>\d - dígitos (0-9)
# <br>\D - exceto dígitos (0-9)
# <br>\w - palavra (a-z, A-Z, 0-9, \_)
# <br>\s - espaço em branco (tab, espaço, nova linha)
# <br>\S - qualquer coisa exceto espaço em branco (tab, espaço, nova linha)
# <br>\b - início de uma palavra
# <br>\B - exceto início da palavra
# <br>^ - inicio de uma String
# <br>$ - final de uma string
# <br>[] - caracteres em colchetes
# <br>[^] - caracteres não em colchetes
# <br>| - ou
# <br>( ) - grupo
#
# <br>* - nenhum ou mais
# <br>+ - um ou mais
# <br>? - nenhum ou um
# <br>{3} - número exato
# <br>{3,4} - range de Números (mínimo, máximo)
#
# Referência (inglês):
# http://bit.ly/ExpressoesRegulares

# %% [markdown]
# # Engenharia de Recursos - Feature Engineering

# %% [markdown]
# ## Mudando Valores Linha Por Linha - iterrows()
